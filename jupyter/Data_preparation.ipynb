# %%
import pandas as pd
import numpy as np
from google.colab import drive
from geopy.geocoders import Nominatim
from geopy.point import Point
import warnings
warnings.filterwarnings('ignore')

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
def make_df_dtype(data):
    '''
    Создает датафрейм для анализа исходного фрейма по каждому признаку.
    Каждая строка соответствует столбцу исходного датафрейма и предоставляет информацию:
    - тип данных
    - количество уникальных значений
    - процент пропущенных значений

    Args:
        data (DataFrame): Датафремй для анализа

    Returns:
        df(DataFrame): Сформированный датафрейм
    '''

    cols, dtype_col, nunique, null_share = [], [], [], []
    for column in data:
        cols.append(column)

        this_dtype = data[column].dtype
        dtype_col.append(this_dtype)

        nunique.append(data[column].nunique())

        null_sum = data[column].isna().sum()
        null_to_len = null_sum / len(data[column])
        null_share.append(f'{null_to_len:.2%}')

    df = pd.DataFrame(list(zip(dtype_col,
                               nunique,
                              null_share)),
                      index=cols)
    df.columns=['dtype',
                'nunique',
               'null_share']

    return df

# %%
def get_country(row):
  '''
    Определяет страну по координатам через обращение к сервису geolocator.

    Args:
        row (pandas.core.series.Series): строка датафрейма

    Returns:
        наименование страны или np.nan в случае ошибки
    '''
    #pos = str(row['lat']) + ', ' + str(row['lng'])
  geolocator = Nominatim(user_agent="http")
  try:
      location = geolocator.reverse(Point(row['lat'], row['lng']), timeout = 10)
      return location.raw.get('address').get('country')
  except ValueError:
      return np.nan

# %%
def validate_country(row):
  '''
    Определяет страну по координатам через обращение к сервису geolocator.

    Args:
        row (pandas.core.series.Series): строка датафрейма

    Returns:
        наименование страны или np.nan в случае ошибки
    '''
    #pos = str(row['lat']) + ', ' + str(row['lng'])
  geolocator = Nominatim(user_agent="http")
  #dfLat.loc[dfLat.duplicated(subset=dfLat.columns.difference(['lat', 'lng']), keep=False)]
  try:
      location = geolocator.reverse(Point(row['lat'], row['lng']), timeout = 10)
      res = location.raw.get('address').get('country')
      if (res==row['Country']):
        return res
      else:
        return np.nan
  except ValueError:
      return np.nan

# %% [markdown]
# # Предобработка дополнительного датафрейма

# %% [markdown]
# # Работа с пропусками

# %%
dfLat = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Проект/AQI and Lat Long of Countries.csv')

# %% [markdown]
# Этот датарейм используется для заполнения пропущенных стран и широты и долготы в рабочем датафрейме. Прежде чем объединять датасеты слева, я выкину из датасета №2 все строки с пустой долготой и широтой, так как они нам не нужны.

# %%
dfLat.dropna(subset = ['lat', 'lng'], inplace=True)

# %% [markdown]
# Скорректируем названия стран.

# %%
# !pip install country_converter --upgrade
# Out:
# Collecting country_converter
#   Downloading country_converter-1.2-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 853.8 kB/s eta 0:00:00
# Requirement already satisfied: pandas>=1.0 in /usr/local/lib/python3.10/dist-packages (from country_converter) (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0->country_converter) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0->country_converter) (2023.3.post1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0->country_converter) (1.23.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=1.0->country_converter) (1.16.0)
# Installing collected packages: country_converter
# Successfully installed country_converter-1.2

# %% [markdown]
# The input format is determined automatically, based on ISO two letter, ISO three letter, ISO numeric or regular expression matching. In case of any ambiguity, the source format can be specified with the parameter 'src'.

# %%
dfLat.Country.unique()
# Out:
# array(['Russian Federation', 'Brazil', 'Italy', 'Poland',
#        'United States of America', 'Belgium', 'China', 'Netherlands',
#        'France', 'Colombia', 'Romania', 'Indonesia', 'Finland',
#        'South Africa',
#        'United Kingdom of Great Britain and Northern Ireland', 'India',
#        'Haiti', 'Philippines', 'Latvia', 'Germany', 'New Zealand',
#        'Mexico', 'Japan', 'El Salvador', 'Nigeria', 'South Sudan',
#        'Ireland', 'Turkey', 'Democratic Republic of the Congo', 'Canada',
#        'Switzerland', 'Denmark', 'Cameroon', 'Australia', 'Portugal',
#        'Ethiopia', 'Hungary', 'Iran (Islamic Republic of)', 'Israel',
#        "Côte d'Ivoire", 'Papua New Guinea', 'Madagascar', 'Ghana',
#        'Armenia', 'Guatemala', 'Pakistan', 'Thailand', 'Malaysia',
#        'Ecuador', 'Argentina', 'Peru', 'Dominican Republic', 'Azerbaijan',
#        'Spain', 'Guinea', 'Bolivia (Plurinational State of)', 'Chile',
#        'Republic of North Macedonia', 'Kazakhstan', 'Serbia', 'Egypt',
#        'Czechia', 'Malawi', 'Sierra Leone', 'Ukraine', 'Benin', 'Namibia',
#        'Albania', nan, 'Guyana', 'Senegal', 'Lesotho',
#        'Venezuela (Bolivarian Republic of)', 'Bulgaria', 'Somalia',
#        'Solomon Islands', 'Paraguay', 'Zimbabwe', 'Austria', 'Croatia',
#        'Chad', 'Honduras', 'United Republic of Tanzania', 'Cambodia',
#        'Uganda', 'Cuba', 'Uruguay', 'Republic of Moldova', 'Myanmar',
#        'Angola', 'Kingdom of Eswatini', 'Zambia', 'Morocco', 'Slovakia',
#        'Sweden', 'Belarus', 'Norway', 'Mongolia', 'Malta', 'Rwanda',
#        'Botswana', 'Sri Lanka', 'Burundi', 'Jamaica', 'Kenya', 'Slovenia',
#        'Mauritius', 'Nicaragua', 'Uzbekistan', 'Republic of Korea',
#        'Burkina Faso', 'Cabo Verde', 'Mozambique', 'Mauritania',
#        'Guinea-Bissau', 'United Arab Emirates', 'Bangladesh', 'Eritrea',
#        'Barbados', 'Algeria', 'Saudi Arabia', 'Syrian Arab Republic',
#        'Tajikistan', 'Greece', 'Liberia',
#        "Lao People's Democratic Republic", 'Bhutan', 'Costa Rica',
#        'Gambia', 'Kyrgyzstan', 'Lithuania', 'Viet Nam',
#        'Bosnia and Herzegovina', 'Saint Lucia', 'Iraq', 'Mali', 'Georgia',
#        'Libya', 'Niger', 'Central African Republic', 'Sudan',
#        'Trinidad and Tobago', 'Turkmenistan', 'Gabon', 'Estonia',
#        'Panama', 'Togo', 'Congo', 'Comoros', 'Nepal', 'Jordan',
#        'Montenegro', 'Equatorial Guinea', 'Luxembourg', 'Aruba',
#        'Tunisia', 'Belize', 'Andorra', 'Iceland', 'Palau', 'Suriname',
#        'Singapore', 'Maldives', 'Bahrain', 'Lebanon', 'Seychelles',
#        'State of Palestine', 'Cyprus', 'Afghanistan', 'Yemen', 'Oman',
#        'Kuwait', 'Saint Kitts and Nevis', 'Qatar', 'Monaco'], dtype=object)

# %%
import country_converter as coco
cc = coco.CountryConverter()
dfLat['Country'] = dfLat['Country'].apply(lambda x: x if pd.isna(x) else cc.convert(names=x, to='name_short'))

# %% [markdown]
# Стоит обратить внимание на страну которая изначально была записана как Viet Nam)

# %%
dfLat.Country.unique()
# Out:
# array(['Russia', 'Brazil', 'Italy', 'Poland', 'United States', 'Belgium',
#        'China', 'Netherlands', 'France', 'Colombia', 'Romania',
#        'Indonesia', 'Finland', 'South Africa', 'United Kingdom', 'India',
#        'Haiti', 'Philippines', 'Latvia', 'Germany', 'New Zealand',
#        'Mexico', 'Japan', 'El Salvador', 'Nigeria', 'South Sudan',
#        'Ireland', 'Türkiye', 'DR Congo', 'Canada', 'Switzerland',
#        'Denmark', 'Cameroon', 'Australia', 'Portugal', 'Ethiopia',
#        'Hungary', 'Iran', 'Israel', "Cote d'Ivoire", 'Papua New Guinea',
#        'Madagascar', 'Ghana', 'Armenia', 'Guatemala', 'Pakistan',
#        'Thailand', 'Malaysia', 'Ecuador', 'Argentina', 'Peru',
#        'Dominican Republic', 'Azerbaijan', 'Spain', 'Guinea', 'Bolivia',
#        'Chile', 'North Macedonia', 'Kazakhstan', 'Serbia', 'Egypt',
#        'Czechia', 'Malawi', 'Sierra Leone', 'Ukraine', 'Benin', 'Namibia',
#        'Albania', nan, 'Guyana', 'Senegal', 'Lesotho', 'Venezuela',
#        'Bulgaria', 'Somalia', 'Solomon Islands', 'Paraguay', 'Zimbabwe',
#        'Austria', 'Croatia', 'Chad', 'Honduras', 'Tanzania', 'Cambodia',
#        'Uganda', 'Cuba', 'Uruguay', 'Moldova', 'Myanmar', 'Angola',
#        'Eswatini', 'Zambia', 'Morocco', 'Slovakia', 'Sweden', 'Belarus',
#        'Norway', 'Mongolia', 'Malta', 'Rwanda', 'Botswana', 'Sri Lanka',
#        'Burundi', 'Jamaica', 'Kenya', 'Slovenia', 'Mauritius',
#        'Nicaragua', 'Uzbekistan', 'South Korea', 'Burkina Faso',
#        'Cabo Verde', 'Mozambique', 'Mauritania', 'Guinea-Bissau',
#        'United Arab Emirates', 'Bangladesh', 'Eritrea', 'Barbados',
#        'Algeria', 'Saudi Arabia', 'Syria', 'Tajikistan', 'Greece',
#        'Liberia', 'Laos', 'Bhutan', 'Costa Rica', 'Gambia',
#        'Kyrgyz Republic', 'Lithuania', 'Vietnam',
#        'Bosnia and Herzegovina', 'St. Lucia', 'Iraq', 'Mali', 'Georgia',
#        'Libya', 'Niger', 'Central African Republic', 'Sudan',
#        'Trinidad and Tobago', 'Turkmenistan', 'Gabon', 'Estonia',
#        'Panama', 'Togo', 'Congo Republic', 'Comoros', 'Nepal', 'Jordan',
#        'Montenegro', 'Equatorial Guinea', 'Luxembourg', 'Aruba',
#        'Tunisia', 'Belize', 'Andorra', 'Iceland', 'Palau', 'Suriname',
#        'Singapore', 'Maldives', 'Bahrain', 'Lebanon', 'Seychelles',
#        'Palestine', 'Cyprus', 'Afghanistan', 'Yemen', 'Oman', 'Kuwait',
#        'St. Kitts and Nevis', 'Qatar', 'Monaco'], dtype=object)

# %% [markdown]
# Проверим есть ли дубликаты без учета широт.

# %%
dup_rows = dfLat.loc[dfLat.duplicated(subset=dfLat.columns.difference(['lat', 'lng']), keep=False)]
dup_rows.shape[0]
# Out:
# 3809

# %% [markdown]
# Добавим дополнительный признак в доп датасет: Дубликат. Для этого воспользуемся функцией. Если наша строка есть в списке дубликатов, то мы ее отмечаем. В дальнейшем это поможет нам убрать некорректные значения стран.

# %%
dfLat.loc[dfLat.duplicated(subset=dfLat.columns.difference(['lat','lng']), keep=False), 'dup'] = 'dup'
dfLat.loc[~dfLat.duplicated(subset=dfLat.columns.difference(['lat','lng']), keep=False), 'dup'] = 'Nor'

# %% [markdown]
# Сделаем валидацию стран вспомогательного датасета. Почему? Потому что нам все равно могут потребоваться координаты. так как мы уже отметили те строки которые являются дублями, но не по координатам, а таких почти 1/4 датасета, то нам надо провалидировать лишь их. Мы возьмем все строки, в которых есть такая отметка и отправим их на проверку страны.
# Берем координаты, отправляем их в валидирующую функцию, которая возвращает либо наименование страны, если координаты совпали, либо возвращает Nan

# %%
dfLat['Country'] = dfLat.apply(lambda row: validate_country(row) if (row['dup']=='dup') else row['Country'], axis = 1)

# %%
dup_rows = dfLat.loc[dfLat.duplicated(subset=dfLat.columns.difference(['lat', 'lng']), keep=False)]
dup_rows.shape[0]
# Out:
# 3225

# %%
dup_rows.head(6)
# Out:
#           Country              City  AQI Value AQI Category  CO AQI Value  \
# 1             NaN  Presidente Dutra         41         Good             1
# 2             NaN  Presidente Dutra         41         Good             1
# 20  United States           Pontiac         77     Moderate             2
# 21  United States           Pontiac         77     Moderate             2
# 33  United States            Dayton         45         Good             1
# 34  United States            Dayton         45         Good             1
#
#    CO AQI Category  Ozone AQI Value Ozone AQI Category  NO2 AQI Value  \
# 1             Good                5               Good              1
# 2             Good                5               Good              1
# 20            Good               22               Good             15
# 21            Good               22               Good             15
# 33            Good               32               Good              7
# 34            Good               32               Good              7
#
#    NO2 AQI Category  PM2.5 AQI Value PM2.5 AQI Category      lat       lng  \
# 1              Good               41               Good  -5.2900  -44.4900
# 2              Good               41               Good -11.2958  -41.9869
# 20             Good               77           Moderate  42.6493  -83.2878
# 21             Good               77           Moderate  40.8894  -88.6409
# 33             Good               45               Good  39.7805  -84.2003
# 34             Good               45               Good  39.2592 -119.5653
#
#     dup
# 1   dup
# 2   dup
# 20  dup
# 21  dup
# 33  dup
# 34  dup

# %% [markdown]
# Остались строки в которых координаты максимально близко, удалить можно любые дубликаты, оставив первый отмеченный как False. Избавимся сначала от проверенных строк с пустой страной и удалим их. (То есть он где-то 1000 строк проверил и вернул 500 пустых строк, и 500 верных). В остальных страны определены верно.

# %%
dfLat = dfLat.drop_duplicates(subset=dfLat.columns.difference(['lat', 'lng']), keep='first')

# %% [markdown]
# Отлично, мы почистили вспомогательный датасет. Проверим какие колонки в нем есть, чтобы сразу удалить ненужные.

# %%
dfLat.dtypes
# Out:
# Country                object
# City                   object
# AQI Value               int64
# AQI Category           object
# CO AQI Value            int64
# CO AQI Category        object
# Ozone AQI Value         int64
# Ozone AQI Category     object
# NO2 AQI Value           int64
# NO2 AQI Category       object
# PM2.5 AQI Value         int64
# PM2.5 AQI Category     object
# lat                   float64
# lng                   float64
# dup                    object
# dtype: object

# %%
dfLat.drop(['dup'], axis=1)
# Out:
#              Country              City  AQI Value AQI Category  CO AQI Value  \
# 0             Russia        Praskoveya         51     Moderate             1
# 1                NaN  Presidente Dutra         41         Good             1
# 3              Italy   Priolo Gargallo         66     Moderate             1
# 4             Poland         Przasnysz         34         Good             1
# 5                NaN       Punta Gorda         54     Moderate             1
# ...              ...               ...        ...          ...           ...
# 16689          China          Shaoguan        160    Unhealthy             3
# 16690  United States  Highland Springs         54     Moderate             1
# 16691            NaN            Martin         71     Moderate             1
# 16693         France            Sceaux         50         Good             1
# 16694  United States       Westerville         71     Moderate             1
#
#       CO AQI Category  Ozone AQI Value Ozone AQI Category  NO2 AQI Value  \
# 0                Good               36               Good              0
# 1                Good                5               Good              1
# 3                Good               39               Good              2
# 4                Good               34               Good              0
# 5                Good               14               Good             11
# ...               ...              ...                ...            ...
# 16689            Good              160          Unhealthy              1
# 16690            Good               34               Good              5
# 16691            Good               39               Good              1
# 16693            Good               20               Good              5
# 16694            Good               44               Good              2
#
#       NO2 AQI Category  PM2.5 AQI Value PM2.5 AQI Category      lat       lng
# 0                 Good               51           Moderate  44.7444   44.2031
# 1                 Good               41               Good  -5.2900  -44.4900
# 3                 Good               66           Moderate  37.1667   15.1833
# 4                 Good               20               Good  53.0167   20.8833
# 5                 Good               54           Moderate  16.1005  -88.8074
# ...                ...              ...                ...      ...       ...
# 16689             Good               79           Moderate  24.8011  113.5927
# 16690             Good               54           Moderate  37.5516  -77.3285
# 16691             Good               71           Moderate  49.0650   18.9219
# 16693             Good               50               Good  48.7786    2.2906
# 16694             Good               71           Moderate  40.1241  -82.9210
#
# [14630 rows x 14 columns]

# %% [markdown]
# Подгрузим основной даасет и сделаем аналогичную проверку названий стран.

# %%
data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Проект/global air pollution dataset.csv')

# %%
data.Country.nunique()
# Out:
# 175

# %%
cc = coco.CountryConverter()
data['Country'] = data['Country'].apply(lambda x: x if pd.isna(x) else cc.convert(names=x, to='name_short'))

# %%
data.Country.nunique()
# Out:
# 175

# %% [markdown]
# Выведем топ 10 с пропущенными странами, чтобы посмотреть по какой причине они пропущенны.

# %%
data.loc[(data.Country.isna())].head(10)
# Out:
#      Country                City  AQI Value AQI Category  CO AQI Value  \
# 535      NaN           Granville         30         Good             1
# 654      NaN  Kingston Upon Hull         33         Good             1
# 787      NaN       New Waterford         20         Good             1
# 801      NaN           Kingstown        163    Unhealthy             0
# 906      NaN            Nanakuli         30         Good             0
# 916      NaN             Lavagna         55     Moderate             1
# 968      NaN           Ladispoli         48         Good             1
# 985      NaN            Dong Hoi         55     Moderate             0
# 1139     NaN             Nettuno         53     Moderate             1
# 1169     NaN         Puebloviejo         71     Moderate             1
#
#      CO AQI Category  Ozone AQI Value Ozone AQI Category  NO2 AQI Value  \
# 535             Good               30               Good              3
# 654             Good               17               Good              8
# 787             Good               18               Good              9
# 801             Good               25               Good              0
# 906             Good               27               Good              0
# 916             Good               38               Good              2
# 968             Good               48               Good              2
# 985             Good               26               Good              0
# 1139            Good               53           Moderate              1
# 1169            Good               16               Good              0
#
#      NO2 AQI Category  PM2.5 AQI Value PM2.5 AQI Category
# 535              Good               25               Good
# 654              Good               33               Good
# 787              Good               20               Good
# 801              Good              163          Unhealthy
# 906              Good               30               Good
# 916              Good               55           Moderate
# 968              Good               34               Good
# 985              Good               55           Moderate
# 1139             Good               23               Good
# 1169             Good               71           Moderate

# %% [markdown]
# Судя по результатам, многие значения просто написаны с не с той буквы. Например Nanakuli, там используются дифтонги. Или в данных опечатка. Мне не хочется удалять такое количество строк из сета, все таки это почти два процента. Поэтому я воспользуюсь вторым датасетом, который был упомянут в Readme. Собственно он для этой цели и планировался. Я объединю два датасета, чтобы получить координаты. А далее по координатам можно будет определить страну.

# %%
data = data.merge(dfLat, how='left')

# %%
data.shape
# Out:
# (23463, 15)

# %% [markdown]
# Подтянула лишнюю колонку с дублями

# %%
data.isna().sum()
# Out:
# Country                427
# City                     1
# AQI Value                0
# AQI Category             0
# CO AQI Value             0
# CO AQI Category          0
# Ozone AQI Value          0
# Ozone AQI Category       0
# NO2 AQI Value            0
# NO2 AQI Category         0
# PM2.5 AQI Value          0
# PM2.5 AQI Category       0
# lat                   9693
# lng                   9693
# dup                   9693
# dtype: int64

# %% [markdown]
# Как видно, количество неизвестных стран осталось тем же, зато теперь у нас есть координаты и мы можем восопльзоваться геосервисом

# %%
pip install geopy
# Out:
# Requirement already satisfied: geopy in /usr/local/lib/python3.10/dist-packages (2.3.0)
# Requirement already satisfied: geographiclib<3,>=1.52 in /usr/local/lib/python3.10/dist-packages (from geopy) (2.0)

# %%
data['Country'] = data.apply(lambda row: get_country(row) if pd.isnull(row['Country']) else row['Country'], axis = 1)

# %% [markdown]
# Проверим заполнились ли данные на примере Nanakuli

# %%
data.loc[(data.City=='Nanakuli')]
# Out:
#            Country      City  AQI Value AQI Category  CO AQI Value  \
# 906  United States  Nanakuli         30         Good             0
#
#     CO AQI Category  Ozone AQI Value Ozone AQI Category  NO2 AQI Value  \
# 906            Good               27               Good              0
#
#     NO2 AQI Category  PM2.5 AQI Value PM2.5 AQI Category      lat       lng  \
# 906             Good               30               Good  21.3892 -158.1445
#
#      dup
# 906  Nor

# %%
dup_rows = data.loc[data.duplicated(subset=data.columns.difference(['lat', 'lng']), keep=False)]
dup_rows.shape[0]
# Out:
# 0

# %%
(data.loc[(data.Country.isna())].shape[0]/data.shape[0])*100
# Out:
# 0.6563525550867323

# %%
data.isna().sum()
# Out:
# Country                154
# City                     1
# AQI Value                0
# AQI Category             0
# CO AQI Value             0
# CO AQI Category          0
# Ozone AQI Value          0
# Ozone AQI Category       0
# NO2 AQI Value            0
# NO2 AQI Category         0
# PM2.5 AQI Value          0
# PM2.5 AQI Category       0
# lat                   9693
# lng                   9693
# dup                   9693
# dtype: int64

# %% [markdown]
# так, у нас осталось 154 строки без страны и координат. Города там написаны явно с грамматической ошибкой. И процент таких строк 0,65%. То мы можем смело их удалить.А вот пустые строки с координатами нас не так сильно беспокоят. Их можно будет заполнить с помощью того же сервиса geopy, если они потребуются

# %%
data.dropna(subset = ['Country'], inplace=True)

# %% [markdown]
# Поле объединения датасетов у нас немного дублей появилось, надо их удалить

# %%
data['City'].nunique()
# Out:
# 23308

# %%
data.drop_duplicates(subset=['City'])
# Out:
#              Country              City  AQI Value AQI Category  CO AQI Value  \
# 0             Russia        Praskoveya         51     Moderate             1
# 1             Brazil  Presidente Dutra         41         Good             1
# 2              Italy   Priolo Gargallo         66     Moderate             1
# 3             Poland         Przasnysz         34         Good             1
# 4             France          Punaauia         22         Good             0
# ...              ...               ...        ...          ...           ...
# 23458          India      Gursahaiganj        184    Unhealthy             3
# 23459         France            Sceaux         50         Good             1
# 23460          India          Mormugao         50         Good             1
# 23461  United States       Westerville         71     Moderate             1
# 23462       Malaysia            Marang         70     Moderate             1
#
#       CO AQI Category  Ozone AQI Value Ozone AQI Category  NO2 AQI Value  \
# 0                Good               36               Good              0
# 1                Good                5               Good              1
# 2                Good               39               Good              2
# 3                Good               34               Good              0
# 4                Good               22               Good              0
# ...               ...              ...                ...            ...
# 23458            Good              154          Unhealthy              2
# 23459            Good               20               Good              5
# 23460            Good               22               Good              1
# 23461            Good               44               Good              2
# 23462            Good               38               Good              0
#
#       NO2 AQI Category  PM2.5 AQI Value PM2.5 AQI Category      lat      lng  \
# 0                 Good               51           Moderate  44.7444  44.2031
# 1                 Good               41               Good      NaN      NaN
# 2                 Good               66           Moderate  37.1667  15.1833
# 3                 Good               20               Good  53.0167  20.8833
# 4                 Good                6               Good      NaN      NaN
# ...                ...              ...                ...      ...      ...
# 23458             Good              184          Unhealthy      NaN      NaN
# 23459             Good               50               Good  48.7786   2.2906
# 23460             Good               50               Good      NaN      NaN
# 23461             Good               71           Moderate  40.1241 -82.9210
# 23462             Good               70           Moderate      NaN      NaN
#
#        dup
# 0      Nor
# 1      NaN
# 2      Nor
# 3      Nor
# 4      NaN
# ...    ...
# 23458  NaN
# 23459  Nor
# 23460  NaN
# 23461  Nor
# 23462  NaN
#
# [23309 rows x 15 columns]

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---
# Дополним данные координатами для полного отображения данных на карте

# %%
data.tail()
# Out:
#              Country          City  AQI Value AQI Category  CO AQI Value  \
# 23458          India  Gursahaiganj        184    Unhealthy             3
# 23459         France        Sceaux         50         Good             1
# 23460          India      Mormugao         50         Good             1
# 23461  United States   Westerville         71     Moderate             1
# 23462       Malaysia        Marang         70     Moderate             1
#
#       CO AQI Category  Ozone AQI Value Ozone AQI Category  NO2 AQI Value  \
# 23458            Good              154          Unhealthy              2
# 23459            Good               20               Good              5
# 23460            Good               22               Good              1
# 23461            Good               44               Good              2
# 23462            Good               38               Good              0
#
#       NO2 AQI Category  PM2.5 AQI Value PM2.5 AQI Category      lat      lng  \
# 23458             Good              184          Unhealthy      NaN      NaN
# 23459             Good               50               Good  48.7786   2.2906
# 23460             Good               50               Good      NaN      NaN
# 23461             Good               71           Moderate  40.1241 -82.9210
# 23462             Good               70           Moderate      NaN      NaN
#
#        dup
# 23458  NaN
# 23459  Nor
# 23460  NaN
# 23461  Nor
# 23462  NaN

# %%
data.isna().sum()
# Out:
# Country                  0
# City                     1
# AQI Value                0
# AQI Category             0
# CO AQI Value             0
# CO AQI Category          0
# Ozone AQI Value          0
# Ozone AQI Category       0
# NO2 AQI Value            0
# NO2 AQI Category         0
# PM2.5 AQI Value          0
# PM2.5 AQI Category       0
# lat                   9539
# lng                   9539
# dup                   9539
# dtype: int64

# %%
from geopandas.tools import geocode
for index,row in data.iterrows():
  if pd.isna(row['lng']):
    try:
      information = geocode(row['City'], provider = 'nominatim', user_agent='xyz', timeout=5)
      data.loc[index, 'lng'] = information.geometry.loc[0].x
      data.loc[index,'lat'] = information.geometry.loc[0].y
    except:
      print('Coordinates of '+row['City']+ ' are not available')
# Out:
# Coordinates of West Carrollton City are not available
# Coordinates of Goryachevodskiy are not available
# Coordinates of Sungaipenuh are not available
# Coordinates of Taburbah are not available
# Coordinates of Ballitoville are not available
# Coordinates of Chilakalurupet are not available
# Coordinates of Kryvyy Rih are not available
# Coordinates of Izyaslav are not available
# Coordinates of Nangloi Jat are not available
# Coordinates of Naravarikuppam are not available
# Coordinates of Lopatinskiy are not available
# Coordinates of Muvattupula are not available
# Coordinates of Masjed E Soleyman are not available
# Coordinates of Houlung are not available
# Coordinates of Phu Khieo are not available
# Coordinates of Dembi Dolo are not available
# Coordinates of Sattankulam are not available
# Coordinates of Yandoon are not available
# Coordinates of Dokshukino are not available
# Coordinates of Energeticheskiy are not available
# Coordinates of Boshkengash are not available
# Coordinates of Sannicolaul Mare are not available
# Coordinates of Apomu are not available
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=5)")': /search?q=Basirhat&format=json&limit=1
# Coordinates of Tecoman are not available
# Coordinates of Thivai are not available
# Coordinates of Tripoli are not available
# Coordinates of Tuysarkan are not available
# Coordinates of Viransehir are not available
# Coordinates of Pandaria are not available
# Coordinates of Parichhatgarh are not available
# Coordinates of Rabwah are not available
# Coordinates of Taklisah are not available
# Coordinates of Tastur are not available
# Coordinates of Kaliwungu are not available
# Coordinates of Escazu are not available
# Coordinates of Boldumsaz are not available
# Coordinates of Boshan are not available
# Coordinates of Bousse are not available
# Coordinates of Chambishi are not available
# Coordinates of Bene Beraq are not available
# Coordinates of Maymanak are not available
# Coordinates of Mehndawal are not available
# Coordinates of Kahna Nau are not available
# Coordinates of Homnabad are not available
# Coordinates of Hsinpu are not available
# Coordinates of Karsiyang are not available
# Coordinates of Nkowakowa are not available
# Coordinates of Krasnozerskoye are not available
# Coordinates of Kurandvad are not available
# Coordinates of Zachagansk are not available
# Coordinates of Zhetysay are not available
# Coordinates of Diyarb Najm are not available
# Coordinates of Ust Ordynskiy are not available
# Coordinates of Starokostyantyniv are not available
# Coordinates of Sanhsia are not available
# Coordinates of Balykshi are not available
# Coordinates of Moskhaton are not available
# Coordinates of Stantsiya Gorchakovo are not available
# Coordinates of Kayattar are not available
# Coordinates of Choucheng are not available
# Coordinates of Panjwin are not available
# Coordinates of Panagjuriste are not available
# Coordinates of Rayadrug are not available
# Coordinates of Pilaia are not available
# Coordinates of Polikhni are not available
# Coordinates of Aryanah are not available
# Coordinates of Sungai Siput Utara are not available
# Coordinates of Diglur are not available
# Coordinates of Nizhneye Kazanishche are not available
# Coordinates of Bhasawar are not available
# Coordinates of Bobrovytsya are not available
# Coordinates of Stryy are not available
# Coordinates of Sikeai are not available
# Coordinates of Vetluzhskiy are not available
# Coordinates of Seryshevo are not available
# Coordinates of Obluche are not available
# Coordinates of Chengkung are not available
# Coordinates of Zmiyiv are not available
# Coordinates of Kafr Yuba are not available
# Coordinates of Gribanovskiy are not available
# Coordinates of Nizhnyaya Maktama are not available
# Coordinates of Palaion Faliron are not available
# Coordinates of Titron are not available
# Coordinates of Tsotsin Yurt are not available
# Coordinates of Manzil Bu Zalafah are not available
# Coordinates of Keratsinion are not available
# Coordinates of Chak Azam Sahu are not available
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=5)")': /search?q=Ara&format=json&limit=1
# Coordinates of Sangareddi are not available
# Coordinates of Kot Putli are not available
# Coordinates of Piriyapatna are not available
# Coordinates of Bardaw are not available
# Coordinates of Khalandrion are not available
# Coordinates of Hsinhua are not available
# Coordinates of Moji Das Cruzes are not available
# Coordinates of Itimadpur are not available
# Coordinates of Novosilikatnyy are not available
# Coordinates of Honavar are not available
# Coordinates of Garui are not available
# Coordinates of Fiditi are not available
# Coordinates of Kasimbazar are not available
# Coordinates of Kaikalur are not available
# Coordinates of Kuanhsi are not available
# Coordinates of Nyzhnya Krynka are not available
# Coordinates of Virarajendrapet are not available
# Coordinates of Oraiokastron are not available
# Coordinates of Pangkalanbuun are not available
# Coordinates of Pinjaur are not available
# Coordinates of Borujan are not available
# Coordinates of Yungkang are not available
# Coordinates of Chuhar Kana are not available
# Coordinates of Tabarqah are not available
# Coordinates of Kattivakkam are not available
# Coordinates of Beypur are not available
# Coordinates of Bin Qirdan are not available
# Coordinates of Yuryev Polskiy are not available
# Coordinates of Juifang are not available
# Coordinates of Kobelyaky are not available
# Coordinates of Kolomyya are not available
# Coordinates of Uvelskiy are not available
# Coordinates of Tyulgan are not available
# Coordinates of Tienchung are not available
# Coordinates of Virapandi are not available
# Coordinates of Tasbuget are not available
# Coordinates of Gopichettipalaiyam are not available
# Coordinates of Galatsion are not available
# Coordinates of Kamensk Shakhtinskiy are not available
# Coordinates of Shaartuz are not available
# Coordinates of Banposh are not available
# Coordinates of Amvrosiyivka are not available
# Coordinates of Akharnai are not available
# Coordinates of Sarai Sidhu are not available
# Coordinates of Fereydun Kenar are not available
# Coordinates of Dundwaraganj are not available
# Coordinates of Nalchiti are not available
# Coordinates of Lalmanir Hat are not available
# Coordinates of Krasnobrodskiy are not available
# Coordinates of Ichnya are not available
# Coordinates of Tattayyangarpettai are not available
# Coordinates of Kharakvasla are not available
# Coordinates of Daltenganj are not available
# Coordinates of Kamskiye Polyany are not available
# Coordinates of Kracheh are not available
# Coordinates of Nea Erithraia are not available
# Coordinates of Sargur are not available
# Coordinates of Jashpurnagar are not available
# Coordinates of Khangah Dogran are not available
# Coordinates of Dod Ballapur are not available
# Coordinates of Savantvadi are not available
# Coordinates of Navadwip are not available
# Coordinates of Madinat Sittah Uktubar are not available
# Coordinates of Pingchen are not available
# Coordinates of Paytug are not available
# Coordinates of Periyanayakkanpalaiyam are not available
# Coordinates of Erhlin are not available
# Coordinates of Shupiyan are not available
# Coordinates of Tiruchchendur are not available
# Coordinates of Tekkalakota are not available
# Coordinates of Thano Bula Khan are not available
# Coordinates of Zhitikara are not available
# Coordinates of Sholokhovskiy are not available
# Coordinates of Ardistan are not available
# Coordinates of Tabulbah are not available
# Coordinates of Psikhikon are not available
# Coordinates of Ulubaria are not available
# Coordinates of Tall Kayf are not available
# Coordinates of Chik Ballapur are not available
# Coordinates of Trjavna are not available
# Coordinates of Waris Aliganj are not available
# Coordinates of Moulmeingyun are not available
# Coordinates of Gaurnadi are not available
# Coordinates of Chinnammanur are not available
# Coordinates of Phalauda are not available
# Coordinates of Mannarakkat are not available
# Coordinates of Adiwerna are not available
# Coordinates of Bail Hongal are not available
# Coordinates of Ekuvukeni are not available
# Coordinates of Provadija are not available
# Coordinates of Anklesvar are not available
# Coordinates of Soldato Aleksandrovskoye are not available
# Coordinates of Vohibinany are not available
# Coordinates of Kamateron are not available
# Coordinates of Qasr Hallal are not available
# Coordinates of Kushchevskaya are not available
# Coordinates of Lar Gerd are not available
# Coordinates of Kafar Qasem are not available
# Coordinates of Kot Kapura are not available
# Coordinates of Lyubotyn are not available
# Coordinates of Pyryatyn are not available
# Coordinates of Qianan are not available
# Coordinates of Asbe Teferi are not available
# Coordinates of Vaghodia are not available
# Coordinates of Vemalwada are not available
# Coordinates of Reftinskiy are not available
# Coordinates of Nawashahr are not available
# Coordinates of Ilanskiy are not available
# Coordinates of Kailasahar are not available
# Coordinates of Chatsu are not available
# Coordinates of Chuhuyiv are not available
# Coordinates of Perumpavur are not available
# Coordinates of Pereslavl Zalesskiy are not available
# Coordinates of Kostyantynivka are not available
# Coordinates of Subaytilah are not available
# Coordinates of Tori Fatehpur are not available
# Coordinates of Kotaparh are not available
# Coordinates of Mancheral are not available
# Coordinates of Gennevillers are not available
# Coordinates of Ndiekro are not available
# Coordinates of Muktagachha are not available
# Coordinates of Shubarkuduk are not available
# Coordinates of Toda Bhim are not available
# Coordinates of Paradwip are not available
# Coordinates of Do Gonbadan are not available
# Coordinates of Maler Kotla are not available
# Coordinates of Manzil Bu Ruqaybah are not available
# Coordinates of Srivardhan are not available
# Coordinates of Judayta are not available
# Coordinates of Gzhatsk are not available
# Coordinates of Baculongan are not available
# Coordinates of Vadakku Valliyur are not available
# Coordinates of Naenwa are not available
# Coordinates of Dhulagari are not available
# Coordinates of Patamundai are not available
# Coordinates of Bolintinu Din Vale are not available
# Coordinates of Addi Ugri are not available
# Coordinates of Lyubinskiy are not available
# Coordinates of Qurunbaliyah are not available
# Coordinates of Lokomotivnyy are not available
# Coordinates of Novyy Buh are not available
# Coordinates of Shimminato are not available
# Coordinates of Suriapet are not available
# Coordinates of Manzil Tamim are not available
# Coordinates of Chettipalaiyam are not available
# Coordinates of Nikolsko Arkhangelskiy are not available
# Coordinates of Rabkavi are not available
# Coordinates of Tirukkattuppalli are not available
# Coordinates of Dzhusaly are not available
# Coordinates of Yandyrka are not available
# Coordinates of Duliagaon are not available
# Coordinates of Tustin Foothills are not available
# Coordinates of Baranchinskiy are not available
# Coordinates of Amarousion are not available
# Coordinates of Chernyakhiv are not available
# Coordinates of Bulanash are not available
# Coordinates of Kuanshan are not available
# Coordinates of Umm Nuwarah are not available
# Coordinates of Hinjilikatu are not available
# Coordinates of Losino Petrovskiy are not available
# Coordinates of Azimur are not available
# Coordinates of Satrikh are not available
# Coordinates of Ogaminana are not available
# Coordinates of Derazhnya are not available
# Coordinates of Zakinthos are not available
# Coordinates of Tsaotun are not available
# Coordinates of Bachhraon are not available
# Coordinates of Inderborskiy are not available
# Coordinates of Chiknayakanhalli are not available
# Coordinates of Krasnousolskiy are not available
# Coordinates of Lonavale are not available
# Coordinates of Urdzhar are not available
# Coordinates of Viraganur are not available
# Coordinates of Silyanah are not available
# Coordinates of Koryukivka are not available
# Coordinates of Akkudah are not available
# Coordinates of Yiannitsa are not available
# Coordinates of Yelbarga are not available
# Coordinates of Changanacheri are not available
# Coordinates of Nimaparha are not available
# Coordinates of Chingshui are not available
# Coordinates of Toda Raisingh are not available
# Coordinates of Suozhen are not available
# Coordinates of Verkhnyaya Sinyachikha are not available
# Coordinates of Pindiga are not available
# Coordinates of Ugleuralskiy are not available
# Coordinates of Belaguntha are not available
# Coordinates of Idenao are not available
# Coordinates of Barka Kana are not available
# Coordinates of Udankudi are not available
# Coordinates of Zheleznogorsk Ilimskiy are not available
# Coordinates of Kualakapuas are not available
# Coordinates of Attayyampatti are not available
# Coordinates of Jagalur are not available
# Coordinates of Kamze are not available
# Coordinates of Aiyion are not available
# Coordinates of Palkonda are not available
# Coordinates of Dhupgari are not available
# Coordinates of Poykovskiy are not available

# %%
data.isna().sum()
# Out:
# Country                  0
# City                     0
# AQI Value                0
# AQI Category             0
# CO AQI Value             0
# CO AQI Category          0
# Ozone AQI Value          0
# Ozone AQI Category       0
# NO2 AQI Value            0
# NO2 AQI Category         0
# PM2.5 AQI Value          0
# PM2.5 AQI Category       0
# lat                    286
# lng                    286
# dup                   9539
# dtype: int64

# %% [markdown]
# Посмотрим, на пустые строки. Сначала на город:

# %%
data = data.reset_index(drop=True)

# %%
data.loc[pd.isna(data['City'])]
# Out:
#      Country City  AQI Value AQI Category  CO AQI Value CO AQI Category  \
# 2628  Israel  NaN         68     Moderate             1            Good
#
#       Ozone AQI Value Ozone AQI Category  NO2 AQI Value NO2 AQI Category  \
# 2628               48               Good              4             Good
#
#       PM2.5 AQI Value PM2.5 AQI Category        lat        lng  dup
# 2628               68           Moderate  46.314475  11.048029  NaN

# %% [markdown]
# Его можно поправить вруную.

# %%
data['City'][2628]= 'Jerusalem'

# %%
data.iloc[[2628]]
# Out:
#      Country       City  AQI Value AQI Category  CO AQI Value CO AQI Category  \
# 2628  Israel  Jerusalem         68     Moderate             1            Good
#
#       Ozone AQI Value Ozone AQI Category  NO2 AQI Value NO2 AQI Category  \
# 2628               48               Good              4             Good
#
#       PM2.5 AQI Value PM2.5 AQI Category        lat        lng  dup
# 2628               68           Moderate  46.314475  11.048029  NaN

# %%
data.drop(['dup'], axis=1, inplace=True)

# %% [markdown]
# Теперь посмотрим что можно сделать с пустыми координатами для городов в названии которых есть ошибка.

# %%
data.loc[pd.isna(data['lat'])]
# Out:
#              Country                  City  AQI Value  \
# 153    United States  West Carrollton City         84
# 179           Russia       Goryachevodskiy         48
# 193        Indonesia           Sungaipenuh         17
# 199          Tunisia              Taburbah         49
# 278     South Africa          Ballitoville        222
# ...              ...                   ...        ...
# 22999        Albania                 Kamze         60
# 23073         Greece                Aiyion         78
# 23160          India              Palkonda        110
# 23187          India              Dhupgari        154
# 23198         Russia            Poykovskiy         43
#
#                          AQI Category  CO AQI Value CO AQI Category  \
# 153                          Moderate             3            Good
# 179                              Good             1            Good
# 193                              Good             1            Good
# 199                              Good             1            Good
# 278                    Very Unhealthy            12            Good
# ...                               ...           ...             ...
# 22999                        Moderate             1            Good
# 23073                        Moderate             1            Good
# 23160  Unhealthy for Sensitive Groups             2            Good
# 23187                       Unhealthy             5            Good
# 23198                            Good             1            Good
#
#        Ozone AQI Value Ozone AQI Category  NO2 AQI Value NO2 AQI Category  \
# 153                  9               Good             24             Good
# 179                 39               Good              1             Good
# 193                 13               Good              0             Good
# 199                 49               Good              1             Good
# 278                  5               Good             14             Good
# ...                ...                ...            ...              ...
# 22999               44               Good              2             Good
# 23073               40               Good              0             Good
# 23160               35               Good              3             Good
# 23187               15               Good             11             Good
# 23198               28               Good              0             Good
#
#        PM2.5 AQI Value              PM2.5 AQI Category  lat  lng
# 153                 84                        Moderate  NaN  NaN
# 179                 48                            Good  NaN  NaN
# 193                 17                            Good  NaN  NaN
# 199                 32                            Good  NaN  NaN
# 278                222                  Very Unhealthy  NaN  NaN
# ...                ...                             ...  ...  ...
# 22999               60                        Moderate  NaN  NaN
# 23073               78                        Moderate  NaN  NaN
# 23160              110  Unhealthy for Sensitive Groups  NaN  NaN
# 23187              154                       Unhealthy  NaN  NaN
# 23198               43                            Good  NaN  NaN
#
# [286 rows x 14 columns]

# %% [markdown]
# Принимая во внимание объем выборки, объем подвыборки с нехаполненными координатами, а также какие именно города попали в подвыборку - принято решение удалить данную подвыборку.

# %%
data.shape
# Out:
# (23309, 14)

# %%
data= data.dropna()

# %%
data.shape
# Out:
# (23023, 14)

# %%
data.to_csv('finalData.csv')
